# %%
from google.cloud import bigquery
import os
import plotly.express as px
import pandas as pd


# Option A : Via variable d'environnement (Recommandé) 
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../data/auth/sante-et-territoires-216daad01024.json" 
client = bigquery.Client() 
# Option B : Directement dans le code# 
#client = bigquery.Client.from_service_account_json("C:\\Users\stefl\Documents\Projet\sante-et-territoires-216daad01024.json")
#export GOOGLE_APPLICATION_CREDENTIALS="C:\Users\stefl\Documents\Projet\sante-et-territoires-216daad01024.json"

#client = bigquery.Client()

query = """
SELECT *
FROM `sante-et-territoires.sante.finess_occitanie_clean`
"""


df_communes = pd.read_csv("../data/geo/communes-france-2025.csv", sep=",", encoding="utf-8")



df = client.query(query).to_dataframe()
# Out:
# /tmp/ipykernel_14119/3219889902.py:22: DtypeWarning: Columns (1,9,11,13,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_communes = pd.read_csv("../data/geo/communes-france-2025.csv", sep=",", encoding="utf-8")

# %%
#filtre sur les communes de l'occitanie
df_communes_occitanie = df_communes[df_communes['reg_nom'] == 'Occitanie']

# %%
# latitudes longitudes en float
df['latitude'] = df['latitude'].astype(float)
df['longitude'] = df['longitude'].astype(float)

# %%
#création d'une carte des Hopitaux cliniques
import plotly.express as px

# 1. Filtrer sur un groupe
df_filtre = df[df['type d etablissements'] == "Hopitaux cliniques"]




# 2. Créer la carte (nouvelle API)
fig = px.scatter_map(
    df_filtre,
    lat="latitude",
    lon="longitude",
    hover_name="raison_sociale",
    hover_data={
        "libelle activite": True,
        "latitude": False,
        "longitude": False
    },
    color="type d etablissements",
    zoom=5,
    height=700
)

# 3. Style de carte (plus de mapbox_style)
fig.update_layout(
    map_style="open-street-map",   # nouvelle syntaxe
    margin={"r":0, "t":0, "l":0, "b":0}
)

fig.show()

# %%
#type d etablissements qui ont le champ soin renseigné
df_soin = df[df['libelle activite'].notna()]
print(df_soin['type d etablissements'].unique())
# Out:
# ['Hopitaux cliniques' 'Soins de ville' 'Autres'
#  'Coordination / Administration' "Centres d'accueil"]

# %%
df_soin = df[df['libelle activite'].notna()]

df_soin[['type d etablissements', 'libelle activite']]
# Out:
#       type d etablissements                                   libelle activite
# 1        Hopitaux cliniques  Traitement de l'insuffisance rénale chronique ...
# 2        Hopitaux cliniques  Traitement de l'insuffisance rénale chronique ...
# 3        Hopitaux cliniques  Traitement de l'insuffisance rénale chronique ...
# 4        Hopitaux cliniques  Traitement de l'insuffisance rénale chronique ...
# 36       Hopitaux cliniques                                 Médecine d'urgence
# ...                     ...                                                ...
# 13511        Soins de ville                                            AMP DPN
# 13743    Hopitaux cliniques                              Soins de longue durée
# 13744    Hopitaux cliniques                              Soins de longue durée
# 13745    Hopitaux cliniques                              Soins de longue durée
# 13746    Hopitaux cliniques                              Soins de longue durée
#
# [1065 rows x 2 columns]

# %%
df_filtre = df[df['type d etablissements'] == "Hopitaux cliniques"]
df_filtre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2193 entries, 1 to 13746
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   numero finess etablissement juridique   754 non-null    object
#  1   numero finess etablissement             2193 non-null   object
#  2   libelle description equipement sociaux  754 non-null    object
#  3   libta_equipement                        754 non-null    object
#  4   rsej                                    1013 non-null   object
#  5   activite                                1013 non-null   object
#  6   libelle activite                        1013 non-null   object
#  7   forme                                   1013 non-null   object
#  8   libelle forme                           1013 non-null   object
#  9   nofinessej_1                            2193 non-null   object
#  10  raison_sociale                          2193 non-null   object
#  11  rslongue                                2106 non-null   object
#  12  code commune                            2193 non-null   object
#  13  departement                             2193 non-null   object
#  14  libelle departement                     2193 non-null   object
#  15  categetab                               2193 non-null   object
#  16  categorie                               2193 non-null   object
#  17  latitude                                2193 non-null   float64
#  18  longitude                               2193 non-null   float64
#  19  type d etablissements                   2193 non-null   object
#  20  code_insee                              2193 non-null   object
# dtypes: float64(2), object(19)
# memory usage: 376.9+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13747 entries, 0 to 13746
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   numero finess etablissement juridique   8035 non-null   object
#  1   numero finess etablissement             13747 non-null  object
#  2   libelle description equipement sociaux  8035 non-null   object
#  3   libta_equipement                        8035 non-null   object
#  4   rsej                                    1065 non-null   object
#  5   activite                                1065 non-null   object
#  6   libelle activite                        1065 non-null   object
#  7   forme                                   1065 non-null   object
#  8   libelle forme                           1065 non-null   object
#  9   nofinessej_1                            13747 non-null  object
#  10  raison_sociale                          13747 non-null  object
#  11  rslongue                                12584 non-null  object
#  12  code commune                            13747 non-null  object
#  13  departement                             13747 non-null  object
#  14  libelle departement                     13747 non-null  object
#  15  categetab                               13747 non-null  object
#  16  categorie                               13747 non-null  object
#  17  latitude                                13747 non-null  float64
#  18  longitude                               13747 non-null  float64
#  19  type d etablissements                   13747 non-null  object
#  20  code_insee                              13747 non-null  object
# dtypes: float64(2), object(19)
# memory usage: 2.2+ MB

# %%
# Je crée un dataframe pour les urgences uniquement 
df_urgences = df[df['libelle activite'].str.contains("urgence", case=False, na=False)]

# %%
df_urgences.head()
# Out:
#     numero finess etablissement juridique numero finess etablissement  \
# 36                                   None                    90000183
# 50                                   None                    90000175
# 52                                   None                    90000175
# 556                                  None                   110000023
# 559                                  None                   110000023
#
#     libelle description equipement sociaux libta_equipement  \
# 36                                    None             None
# 50                                    None             None
# 52                                    None             None
# 556                                   None             None
# 559                                   None             None
#
#                     rsej activite    libelle activite forme   libelle forme  \
# 36   CH ARIEGE COUSERANS     14.0  Médecine d'urgence  14.0  Non saisonnier
# 50                 CHIVA     14.0  Médecine d'urgence  14.0  Non saisonnier
# 52                 CHIVA     14.0  Médecine d'urgence   0.0    Pas de forme
# 556       CH CARCASSONNE     14.0  Médecine d'urgence  14.0  Non saisonnier
# 559       CH CARCASSONNE     14.0  Médecine d'urgence   0.0    Pas de forme
#
#     nofinessej_1  ...                                           rslongue  \
# 36      90781816  ...  CENTRE HOSPITALIER ARIEGE COUSERANS SITE SAINT...
# 50      90781774  ...                    CHIVA SITE SAINT JEAN DE VERGES
# 52      90781774  ...                    CHIVA SITE SAINT JEAN DE VERGES
# 556    110780061  ...     CENTRE HOSPITALIER CARCASSONNE ANTOINE GAYRAUD
# 559    110780061  ...     CENTRE HOSPITALIER CARCASSONNE ANTOINE GAYRAUD
#
#     code commune departement libelle departement categetab  \
# 36           268          09              ARIEGE       355
# 50           264          09              ARIEGE       355
# 52           264          09              ARIEGE       355
# 556           69          11                AUDE       355
# 559           69          11                AUDE       355
#
#                      categorie   latitude  longitude  type d etablissements  \
# 36   Centre Hospitalier (C.H.)  42.999011   1.128549     Hopitaux cliniques
# 50   Centre Hospitalier (C.H.)  43.028346   1.615951     Hopitaux cliniques
# 52   Centre Hospitalier (C.H.)  43.028346   1.615951     Hopitaux cliniques
# 556  Centre Hospitalier (C.H.)  43.219178   2.399894     Hopitaux cliniques
# 559  Centre Hospitalier (C.H.)  43.219178   2.399894     Hopitaux cliniques
#
#     code_insee
# 36       09268
# 50       09264
# 52       09264
# 556       1169
# 559       1169
#
# [5 rows x 21 columns]

# %% [markdown]
# Fonction Haversine (distance en km)
# 🌍 Principe général
# La Terre est (approximativement) une sphère.
# Pour calculer la distance entre deux points sur une sphère, on ne peut pas utiliser la distance euclidienne classique.
# La formule de Haversine permet de calculer la distance orthodromique, c’est‑à‑dire la distance la plus courte entre deux points à la surface de la Terre.

# %%
import numpy as np

def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # rayon de la Terre en km
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    return R * c

# %%
df_communes_occitanie.head()
# Out:
#       Unnamed: 0 code_insee   nom_standard nom_sans_accent  \
# 2813        2813       9001  Aigues-Juntes   aigues-juntes
# 2814        2814       9002   Aigues-Vives    aigues-vives
# 2815        2815       9003    L'Aiguillon     l-aiguillon
# 2816        2816       9004         Albiès          albies
# 2817        2817       9005           Aleu            aleu
#
#      nom_standard_majuscule typecom typecom_texte  reg_code    reg_nom  \
# 2813          AIGUES-JUNTES     COM       commune        76  Occitanie
# 2814           AIGUES-VIVES     COM       commune        76  Occitanie
# 2815            L'AIGUILLON     COM       commune        76  Occitanie
# 2816                 ALBIÈS     COM       commune        76  Occitanie
# 2817                   ALEU     COM       commune        76  Occitanie
#
#      dep_code  ... code_unite_urbaine taille_unite_urbaine population  \
# 2813        9  ...               9000                  0.0         58
# 2814        9  ...               9000                  0.0        634
# 2815        9  ...               9000                  0.0        379
# 2816        9  ...               9000                  0.0        121
# 2817        9  ...               9000                  0.0        126
#
#      superficie_hectare superficie_km2  densite  latitude_centre  \
# 2813                770              8      8.0           43.051
# 2814                522              5    121.0           43.001
# 2815                646              6     59.0           42.910
# 2816                779              8     16.0           42.754
# 2817               1410             14      9.0           42.894
#
#      longitude_centre grille_densite           grille_densite_texte
# 2813            1.472              7  Rural à habitat très dispersé
# 2814            1.877              6       Rural à habitat dispersé
# 2815            1.900              6       Rural à habitat dispersé
# 2816            1.698              6       Rural à habitat dispersé
# 2817            1.268              7  Rural à habitat très dispersé
#
# [5 rows x 28 columns]

# %%
# On crée une matrice de distances
distances = []

for idx, commune in df_communes_occitanie.iterrows():
    lat_c, lon_c = commune['latitude_centre'], commune['longitude_centre']
    
    # distances entre la commune et tous les établissements d'urgence
    d = haversine(
        lat_c, lon_c,
        df_urgences['latitude'].values,
        df_urgences['longitude'].values
    )
    
    # distance minimale = établissement le plus proche
    distances.append(d.min())

df_communes_occitanie['distance_urgence_km'] = distances
# Out:
# /tmp/ipykernel_14376/795381311.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#distance moyenne à l'urgence en  occitanie
distance_moyenne = df_communes_occitanie['distance_urgence_km'].mean()
distance_moyenne
# Out:
# np.float64(17.33704782082205)

# %%
distance_par_dep = (
    df_communes_occitanie
    .groupby('dep_code')['distance_urgence_km']
    .mean()
    .reset_index()
    .sort_values('distance_urgence_km')
)

# %%
#csv des distances des communes aux urgences en occitanie
df_communes_occitanie.to_csv("../../data/processed/distances_communes_urgence_occitanie.csv", index=False)

# %%
df_communes_occitanie.head()
# Out:
#       Unnamed: 0 code_insee   nom_standard nom_sans_accent  \
# 2813        2813       9001  Aigues-Juntes   aigues-juntes
# 2814        2814       9002   Aigues-Vives    aigues-vives
# 2815        2815       9003    L'Aiguillon     l-aiguillon
# 2816        2816       9004         Albiès          albies
# 2817        2817       9005           Aleu            aleu
#
#      nom_standard_majuscule typecom typecom_texte  reg_code    reg_nom  \
# 2813          AIGUES-JUNTES     COM       commune        76  Occitanie
# 2814           AIGUES-VIVES     COM       commune        76  Occitanie
# 2815            L'AIGUILLON     COM       commune        76  Occitanie
# 2816                 ALBIÈS     COM       commune        76  Occitanie
# 2817                   ALEU     COM       commune        76  Occitanie
#
#      dep_code  ... taille_unite_urbaine population superficie_hectare  \
# 2813        9  ...                  0.0         58                770
# 2814        9  ...                  0.0        634                522
# 2815        9  ...                  0.0        379                646
# 2816        9  ...                  0.0        121                779
# 2817        9  ...                  0.0        126               1410
#
#      superficie_km2 densite  latitude_centre  longitude_centre grille_densite  \
# 2813              8     8.0           43.051             1.472              7
# 2814              5   121.0           43.001             1.877              6
# 2815              6    59.0           42.910             1.900              6
# 2816              8    16.0           42.754             1.698              6
# 2817             14     9.0           42.894             1.268              7
#
#                grille_densite_texte  distance_urgence_km
# 2813  Rural à habitat très dispersé            11.967049
# 2814       Rural à habitat dispersé            21.440885
# 2815       Rural à habitat dispersé            23.506510
# 2816       Rural à habitat dispersé            31.229638
# 2817  Rural à habitat très dispersé            16.284241
#
# [5 rows x 29 columns]

# %%
df_urgences.head()
# Out:
#     numero finess etablissement juridique numero finess etablissement  \
# 36                                   None                    90000183
# 50                                   None                    90000175
# 52                                   None                    90000175
# 556                                  None                   110000023
# 559                                  None                   110000023
#
#     libelle description equipement sociaux libta_equipement  \
# 36                                    None             None
# 50                                    None             None
# 52                                    None             None
# 556                                   None             None
# 559                                   None             None
#
#                     rsej activite    libelle activite forme   libelle forme  \
# 36   CH ARIEGE COUSERANS     14.0  Médecine d'urgence  14.0  Non saisonnier
# 50                 CHIVA     14.0  Médecine d'urgence  14.0  Non saisonnier
# 52                 CHIVA     14.0  Médecine d'urgence   0.0    Pas de forme
# 556       CH CARCASSONNE     14.0  Médecine d'urgence  14.0  Non saisonnier
# 559       CH CARCASSONNE     14.0  Médecine d'urgence   0.0    Pas de forme
#
#     nofinessej_1  ...                                           rslongue  \
# 36      90781816  ...  CENTRE HOSPITALIER ARIEGE COUSERANS SITE SAINT...
# 50      90781774  ...                    CHIVA SITE SAINT JEAN DE VERGES
# 52      90781774  ...                    CHIVA SITE SAINT JEAN DE VERGES
# 556    110780061  ...     CENTRE HOSPITALIER CARCASSONNE ANTOINE GAYRAUD
# 559    110780061  ...     CENTRE HOSPITALIER CARCASSONNE ANTOINE GAYRAUD
#
#     code commune departement libelle departement categetab  \
# 36           268          09              ARIEGE       355
# 50           264          09              ARIEGE       355
# 52           264          09              ARIEGE       355
# 556           69          11                AUDE       355
# 559           69          11                AUDE       355
#
#                      categorie   latitude  longitude  type d etablissements  \
# 36   Centre Hospitalier (C.H.)  42.999011   1.128549     Hopitaux cliniques
# 50   Centre Hospitalier (C.H.)  43.028346   1.615951     Hopitaux cliniques
# 52   Centre Hospitalier (C.H.)  43.028346   1.615951     Hopitaux cliniques
# 556  Centre Hospitalier (C.H.)  43.219178   2.399894     Hopitaux cliniques
# 559  Centre Hospitalier (C.H.)  43.219178   2.399894     Hopitaux cliniques
#
#     code_insee
# 36       09268
# 50       09264
# 52       09264
# 556       1169
# 559       1169
#
# [5 rows x 21 columns]

# %%
df_join = pd.read_csv("../../data/processed/finess_occitanie_join.csv")




# Calculs KPI
print(  'Personnes par établissement: ' + str(df_communes_occitanie["population"].sum()/df['numero finess etablissement'].nunique() ) )
# Out:
# Personnes par établissement: 601.9768092762895

# %%
df_cc = df_join[df_join['epci_nom'] == 'CC Pyrénées Audoises']

# %%
df_cc.head()
# Out:
#      numero finess etablissement juridique  numero finess etablissement  \
# 535                                    NaN                    110782455
# 561                                    NaN                    110007598
# 570                                    NaN                    110780236
# 590                                    NaN                    110780194
# 602                                    NaN                    110007374
#
#     libelle description equipement sociaux libta_equipement            rsej  \
# 535                                    NaN              NaN             NaN
# 561                                    NaN              NaN  CH CARCASSONNE
# 570                                    NaN              NaN             NaN
# 590                                    NaN              NaN             NaN
# 602                                    NaN              NaN             NaN
#
#      activite    libelle activite  forme   libelle forme  nofinessej_1  ...  \
# 535       NaN                 NaN    NaN             NaN     110787017  ...
# 561      14.0  Médecine d'urgence   14.0  Non saisonnier     110780061  ...
# 570       NaN                 NaN    NaN             NaN     110780707  ...
# 590       NaN                 NaN    NaN             NaN     330050899  ...
# 602       NaN                 NaN    NaN             NaN     110786324  ...
#
#     code_unite_urbaine taille_unite_urbaine  population  superficie_hectare  \
# 535            11111.0                  1.0      3066.0              2195.0
# 561            11111.0                  1.0      3066.0              2195.0
# 570            11111.0                  1.0      3066.0              2195.0
# 590            11000.0                  0.0      1144.0              1605.0
# 602            11111.0                  1.0      3066.0              2195.0
#
#     superficie_km2  densite latitude_centre  longitude_centre  grille_densite  \
# 535           22.0    140.0          42.876             2.191             5.0
# 561           22.0    140.0          42.876             2.191             5.0
# 570           22.0    140.0          42.876             2.191             5.0
# 590           16.0     71.0          42.982             2.010             5.0
# 602           22.0    140.0          42.876             2.191             5.0
#
#     grille_densite_texte
# 535        Bourgs ruraux
# 561        Bourgs ruraux
# 570        Bourgs ruraux
# 590        Bourgs ruraux
# 602        Bourgs ruraux
#
# [5 rows x 48 columns]

# %%
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 535 to 1274
# Data columns (total 48 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   numero finess etablissement juridique   23 non-null     float64
#  1   numero finess etablissement             39 non-null     int64
#  2   libelle description equipement sociaux  23 non-null     object
#  3   libta_equipement                        23 non-null     object
#  4   rsej                                    1 non-null      object
#  5   activite                                1 non-null      float64
#  6   libelle activite                        1 non-null      object
#  7   forme                                   1 non-null      float64
#  8   libelle forme                           1 non-null      object
#  9   nofinessej_1                            39 non-null     int64
#  10  raison_sociale                          39 non-null     object
#  11  rslongue                                39 non-null     object
#  12  code commune                            39 non-null     int64
#  13  departement                             39 non-null     int64
#  14  libelle departement                     39 non-null     object
#  15  categetab                               39 non-null     int64
#  16  categorie                               39 non-null     object
#  17  latitude                                39 non-null     float64
#  18  longitude                               39 non-null     float64
#  19  type d etablissements                   39 non-null     object
#  20  code_insee                              39 non-null     int64
#  21  Unnamed: 0                              39 non-null     float64
#  22  nom_standard                            39 non-null     object
#  23  nom_sans_accent                         39 non-null     object
#  24  nom_standard_majuscule                  39 non-null     object
#  25  typecom                                 39 non-null     object
#  26  typecom_texte                           39 non-null     object
#  27  reg_code                                39 non-null     float64
#  28  reg_nom                                 39 non-null     object
#  29  dep_code                                39 non-null     float64
#  30  dep_nom                                 39 non-null     object
#  31  canton_code                             39 non-null     float64
#  32  canton_nom                              39 non-null     object
#  33  epci_code                               39 non-null     float64
#  34  epci_nom                                39 non-null     object
#  35  code_postal                             39 non-null     float64
#  36  zone_emploi                             39 non-null     float64
#  37  code_insee_centre_zone_emploi           39 non-null     float64
#  38  code_unite_urbaine                      39 non-null     float64
#  39  taille_unite_urbaine                    39 non-null     float64
#  40  population                              39 non-null     float64
#  41  superficie_hectare                      39 non-null     float64
#  42  superficie_km2                          39 non-null     float64
#  43  densite                                 39 non-null     float64
#  44  latitude_centre                         39 non-null     float64
#  45  longitude_centre                        39 non-null     float64
#  46  grille_densite                          39 non-null     float64
#  47  grille_densite_texte                    39 non-null     object
# dtypes: float64(22), int64(6), object(20)
# memory usage: 14.9+ KB

# %%
df_communes_met_cc = df_communes_occitanie[df_communes_occitanie['epci_code'] == '200043776']

# %%
df_communes_met_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 3586 to 3985
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     61 non-null     int64
#  1   code_insee                     61 non-null     object
#  2   nom_standard                   61 non-null     object
#  3   nom_sans_accent                61 non-null     object
#  4   nom_standard_majuscule         61 non-null     object
#  5   typecom                        61 non-null     object
#  6   typecom_texte                  61 non-null     object
#  7   reg_code                       61 non-null     int64
#  8   reg_nom                        61 non-null     object
#  9   dep_code                       61 non-null     object
#  10  dep_nom                        61 non-null     object
#  11  canton_code                    61 non-null     object
#  12  canton_nom                     61 non-null     object
#  13  epci_code                      61 non-null     object
#  14  epci_nom                       61 non-null     object
#  15  code_postal                    61 non-null     float64
#  16  zone_emploi                    61 non-null     float64
#  17  code_insee_centre_zone_emploi  61 non-null     object
#  18  code_unite_urbaine             61 non-null     object
#  19  taille_unite_urbaine           61 non-null     float64
#  20  population                     61 non-null     int64
#  21  superficie_hectare             61 non-null     int64
#  22  superficie_km2                 61 non-null     int64
#  23  densite                        61 non-null     float64
#  24  latitude_centre                61 non-null     float64
#  25  longitude_centre               61 non-null     float64
#  26  grille_densite                 61 non-null     int64
#  27  grille_densite_texte           61 non-null     object
#  28  distance_urgence_km            61 non-null     float64
# dtypes: float64(7), int64(6), object(16)
# memory usage: 14.3+ KB
