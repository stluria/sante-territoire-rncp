# %%
CREATE OR REPLACE TABLE `sante-et-territoires.finess.soin_etab` AS
SELECT e.nofinesset AS nofinesset,
a.rsej AS rsej,
a.activite AS activite,
a.libactivite AS libactivite,
a.forme AS forme,
a.libforme AS libforme,
e.nofinessej AS nofinessej,
e.rs AS rs,
e.rslongue AS rslongue,
e.commune AS commune,
e.departement AS departement,
e.libdepartement AS libdepartement,
e.categetab AS categetab,
e.libcategetab AS libcategetab,
e.coordyet AS coordyet,
e.coordxet AS coordxet
FROM `sante-et-territoires.finess.finess_activites_soin_clean` AS a
LEFT JOIN `sante-et-territoires.finess.finess_etablissements_clean` AS e
ON a.nofinesset = e.nofinesset

# %% [markdown]
# Jointure

# %% [markdown]
# CCREATE OR REPLACE TABLE `sante-et-territoires.finess.equipements_sociaux_etabl` AS
# SELECT
#   s.nofinesset AS nofinesset,
#   s.de_equipement AS de_equipement,
#   s.libde_equipement AS libde_equipement,
#   s.libta_equipement AS libta_equipement,
#   s.capinstot AS capinstot,
#
#   e.nofinessej AS nofinessej,
#   e.rs AS rs,
#   e.rslongue AS rslongue,
#   e.commune AS commune,
#   e.departement AS departement,
#   e.libdepartement AS libdepartement,
#   e.categetab AS categetab,
#   e.libcategetab AS libcategetab,
#   e.coordyet AS coordyet,
#   e.coordxet AS coordxet,
#
#
# FROM `sante-et-territoires.finess.equipements_sociaux_clean` AS s
# LEFT JOIN `sante-et-territoires.finess.finess_etablissements_clean` AS e
#   ON s.nofinesset = e.nofinesset;
